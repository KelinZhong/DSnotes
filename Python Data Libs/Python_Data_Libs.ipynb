# %% [markdown]
# # Python Data Libraries
#
# The coding-round chapter. Two kinds of notebook live here, and they are used
# differently.
#
# **References** — API lookup, organised by operation. Snippet-style: the code uses
# an undefined `df` / `arr` as a placeholder, so these are read rather than run.
#
# | Notebook | Covers |
# | :--- | :--- |
# | {doc}`Reference_Pandas <Reference_Pandas>` | §1 inspection · §2 selection · §3 nulls · §4 manipulation · §5 joins · §6 groupby · §7 windows · §8 dates · §9 strings · §10 I/O · §11 performance |
# | {doc}`Reference_NumPy <Reference_NumPy>` | §1 creation · §2 dtypes · §3 indexing · §4 reshaping · §5 math · §6 broadcasting · §7 linear algebra · §8 random · §9 performance · §10 set ops, binning & search |
#
# **Workflows** — task-oriented, in the order a real cleaning job happens.
#
# | Notebook | Covers |
# | :--- | :--- |
# | {doc}`DM_Basic <DM_Basic>` | audit · dtypes · missing values · duplicates · string consistency · outliers · column names · validation contracts |
# | {doc}`DM_Intermediate <DM_Intermediate>` | wide/long · groupby patterns · multi-table pipelines · time-series reshaping · nested data · many files · as-of & cross joins |
# | {doc}`DM_Advanced <DM_Advanced>` | encoding · transformations · binning · date features · lag & window features · interactions · text features · leakage |
#
# **Measured** — the one notebook here that executes at build time.
#
# | Notebook | Covers |
# | :--- | :--- |
# | {doc}`Reference_Performance <Reference_Performance>` | iteration vs vectorisation · memory & dtypes · access patterns · copy vs view · larger-than-memory reads · CSV vs Parquet · when to leave pandas |
#
# **Statistics** — review material if you already have a statistics background.
#
# | Notebook | Covers |
# | :--- | :--- |
# | {doc}`Reference_Sampling <Reference_Sampling>` | SRS · stratified · systematic · cluster · bootstrap · jackknife · weighted · stratified K-fold · permutation tests |
# | {doc}`Reference_Inference <Reference_Inference>` | estimation & bias-variance · confidence intervals · testing framework · peeking · one- and two-sample tests · multiple testing · power · sample size & MDE · end-to-end A/B design |
#
# ---
#
# ## Where do I look?
#
# | Question | Go to |
# | :--- | :--- |
# | "How do I write this operation?" | Reference_Pandas / Reference_NumPy |
# | "My data is messy, what's the order of operations?" | DM_Basic |
# | "I need to reshape or join several tables" | DM_Intermediate |
# | "I need model-ready features" | DM_Advanced |
# | "This is too slow / won't fit in memory" | Reference_Performance |
# | "How do I sample this correctly?" | Reference_Sampling |
# | "Is this difference real?" | Reference_Inference |
