# %% [markdown]
# # Python Data Libraries
#
# - Pandas
# - NumPy
# - Data Manipulation (basic, intermediate, advance)
# - Metrics Derivation in Python
# - Sampling with NumPy & Pandas
# - Statistical Inference in Python
